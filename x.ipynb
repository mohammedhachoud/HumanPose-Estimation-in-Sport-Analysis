# %%
from GetMertics2 import main, process_video
video_path = 'Data/Videos/20240608_195713.mp4'
process_video(video_path)

#main(video_path)
# Out:
# 0: 384x640 5 sports balls, 214.9ms
# Speed: 5.3ms preprocess, 214.9ms inference, 1248.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 sports balls, 184.0ms
# Speed: 0.0ms preprocess, 184.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# track id  0
#
# 0: 384x640 5 sports balls, 185.1ms
# Speed: 0.0ms preprocess, 185.1ms inference, 15.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 5 sports balls, 169.8ms
# Speed: 15.6ms preprocess, 169.8ms inference, 15.6ms postprocess per image at shape (1, 3, 384, 640)
# changed in track id  0
# changed in track id  0
# changed in track id  0
#
# 0: 384x640 1 person, 5 sports balls, 200.7ms
# Speed: 15.6ms preprocess, 200.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# changed in track id  0
# happened  22.5  track id   0
#
# 0: 384x640 1 person, 5 sports balls, 244.1ms
# ...
